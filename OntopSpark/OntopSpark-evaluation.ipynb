# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, HiveContext
from pyspark.sql.functions import *
import timeit

# %%
from PySPARQL.Wrapper import PySPARQLWrapper

# %% [markdown]
# ### Connection to Apache Spark

# %%
spark = (SparkSession
          .builder
          .appName("interfacing spark sql to hive metastore without configuration file")
          .config("hive.metastore.uris", "thrift://hive-metastore:9083") 
          .enableHiveSupport() 
          .getOrCreate())

# %% [markdown]
# ### SPARQL query endpoint

# %%
sparql_endpoint = "http://ontop:8080/sparql"

# %% [markdown]
# ### Timeit configuration

# %%
repeat = 10
loop = 1

def Average(lst):
    total = 0
    for ele in range(0, len(lst)):
        total = total + lst[ele]
    return total / len(lst)

# %% [markdown]
# ### Q1

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?value
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:productPropertyNumeric1 ?value .
            # ?product rdf:type bsbm:Product .
            # ?product bsbm:producer ?producer .
            # ?producer rdf:type bsbm:Producer .
            # ?producer foaf:homepage ?hp .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?value > 102)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.4218770640000002, 1.426847763999831, 1.6082297469993136, 1.3164694469996903, 1.2631199130000823, 1.2582888169999933, 1.2783897139997862, 1.2663469479994092, 1.2902684180007782, 1.3214915389999078]
#
# AVG_TIME
# 1.3451329370998792

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?value
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:productPropertyNumeric1 ?value .
            # ?product rdf:type bsbm:Product .
            # ?product bsbm:producer ?producer .
            # ?producer rdf:type bsbm:Producer .
            # ?producer foaf:homepage ?hp .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?value > 102)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +--------------------+-----+
# |               label|value|
# +--------------------+-----+
# |            'ahchoo'|  594|
# |           'coterie'| 1891|
# |'desolates waging...|  374|
# |'lignites rallyin...|  133|
# |    'manner gatemen'|  831|
# |'procreators taiw...| 1504|
# |'reexhibit wrang ...|  940|
# |'resettling uncoa...| 1743|
# |  'tither pettiness'| 1900|
# |'vacillator morti...|  834|
# +--------------------+-----+

# %% [markdown]
# ### Q2

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?label ?comment ?producer ?price
            # ?propertyTextual1 ?propertyTextual2 ?propertyTextual3
            # ?propertyNumeric1 ?propertyNumeric2 ?propertyTextual4
            # ?propertyTextual5 ?propertyNumeric4
        WHERE {
            # ?p rdfs:label ?label .
            # ?p rdfs:comment ?comment .
            # ?p bsbm:producer ?producer .
            # ?p dc:publisher ?ps .
            # ?offer bsbm:product ?p .
            # ?offer bsbm:price ?price .
            # ?p bsbm:productPropertyTextual1 ?propertyTextual1 .
            # ?p bsbm:productPropertyTextual2 ?propertyTextual2 .
            # ?p bsbm:productPropertyTextual3 ?propertyTextual3 .
            # ?p bsbm:productPropertyNumeric1 ?propertyNumeric1 .
            # ?p bsbm:productPropertyNumeric2 ?propertyNumeric2 .
            # ?p bsbm:productPropertyTextual4 ?propertyTextual4 .
            # ?p bsbm:productPropertyTextual5 ?propertyTextual5 .
            # ?p bsbm:productPropertyNumeric4 ?propertyNumeric4 .
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.8792619249998097, 1.939286832000107, 2.178938877999826, 1.7234063119994971, 2.1593382009996276, 1.7946767660005207, 1.8100408649997917, 2.291362152000147, 1.7993365120000817, 1.8837381270004698]
#
# AVG_TIME
# 1.945938656999988

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?label ?comment ?producer ?price
            # ?propertyTextual1 ?propertyTextual2 ?propertyTextual3
            # ?propertyNumeric1 ?propertyNumeric2 ?propertyTextual4
            # ?propertyTextual5 ?propertyNumeric4
        WHERE {
            # ?p rdfs:label ?label .
            # ?p rdfs:comment ?comment .
            # ?p bsbm:producer ?producer .
            # ?p dc:publisher ?ps .
            # ?offer bsbm:product ?p .
            # ?offer bsbm:price ?price .
            # ?p bsbm:productPropertyTextual1 ?propertyTextual1 .
            # ?p bsbm:productPropertyTextual2 ?propertyTextual2 .
            # ?p bsbm:productPropertyTextual3 ?propertyTextual3 .
            # ?p bsbm:productPropertyNumeric1 ?propertyNumeric1 .
            # ?p bsbm:productPropertyNumeric2 ?propertyNumeric2 .
            # ?p bsbm:productPropertyTextual4 ?propertyTextual4 .
            # ?p bsbm:productPropertyTextual5 ?propertyTextual5 .
            # ?p bsbm:productPropertyNumeric4 ?propertyNumeric4 .
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+----------------+----------------+--------------------+--------------------+----------------+
# |               label|             comment|            producer|    price|    propertyTextual1|    propertyTextual2|    propertyTextual3|propertyNumeric1|propertyNumeric2|    propertyTextual4|    propertyTextual5|propertyNumeric4|
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+----------------+----------------+--------------------+--------------------+----------------+
# |            'ahchoo'|'chanceman ventra...|http://example.co...|8.56176E3|'whirs radiation ...|'vichies resituat...|'unreels voicer a...|             594|             434|                null|'hyperbolas knout...|              -1|
# |            'ahchoo'|'chanceman ventra...|http://example.co...|3.03146E3|'whirs radiation ...|'vichies resituat...|'unreels voicer a...|             594|             434|                null|'hyperbolas knout...|              -1|
# |'vacillator morti...|'workaholics situ...|http://example.co...|8.35118E3|'egoisms welterwe...|'unacceptance ant...|'steeper aerifies...|             834|             450|                null|                null|             202|
# |'desolates waging...|'poleward sagest ...|http://example.co...|9.54292E3|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# |  'tither pettiness'|'buskin recompens...|http://example.co...|7.09958E3|'solidest incarna...|'builders preadju...|'dermatologies fl...|            1900|             774|                null|                null|              -1|
# |  'tither pettiness'|'buskin recompens...|http://example.co...|7.15571E3|'solidest incarna...|'builders preadju...|'dermatologies fl...|            1900|             774|                null|                null|              -1|
# |            'ahchoo'|'chanceman ventra...|http://example.co...|6.80574E3|'whirs radiation ...|'vichies resituat...|'unreels voicer a...|             594|             434|                null|'hyperbolas knout...|              -1|
# |            'ahchoo'|'chanceman ventra...|http://example.co...|1.66327E3|'whirs radiation ...|'vichies resituat...|'unreels voicer a...|             594|             434|                null|'hyperbolas knout...|              -1|
# |'resettling uncoa...|'reprice renovati...|http://example.co...|6.17836E3|'unrestored kneel...|'replicates corks...|'cowiest crimpers...|            1743|             136|                null|                null|              -1|
# |'desolates waging...|'poleward sagest ...|http://example.co...|2.12528E3|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# |'reexhibit wrang ...|'bihourly prosies...|http://example.co...|5.76202E3|'skinfuls uncerta...|'quartered mishmo...|'visas deprecatin...|             940|             290|                null|                null|              -1|
# |  'tither pettiness'|'buskin recompens...|http://example.co...|7.57405E3|'solidest incarna...|'builders preadju...|'dermatologies fl...|            1900|             774|                null|                null|              -1|
# |'resettling uncoa...|'reprice renovati...|http://example.co...| 2.0237E3|'unrestored kneel...|'replicates corks...|'cowiest crimpers...|            1743|             136|                null|                null|              -1|
# |'reexhibit wrang ...|'bihourly prosies...|http://example.co...|3.27071E3|'skinfuls uncerta...|'quartered mishmo...|'visas deprecatin...|             940|             290|                null|                null|              -1|
# |'desolates waging...|'poleward sagest ...|http://example.co...|1.23598E3|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# |'vacillator morti...|'workaholics situ...|http://example.co...|2.23648E3|'egoisms welterwe...|'unacceptance ant...|'steeper aerifies...|             834|             450|                null|                null|             202|
# |'desolates waging...|'poleward sagest ...|http://example.co...|6.82051E3|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# |'desolates waging...|'poleward sagest ...|http://example.co...|7.84708E3|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# |'resettling uncoa...|'reprice renovati...|http://example.co...|9.90447E3|'unrestored kneel...|'replicates corks...|'cowiest crimpers...|            1743|             136|                null|                null|              -1|
# |'desolates waging...|'poleward sagest ...|http://example.co...| 3.9302E2|'catarrhs triadis...|'chilblains inter...|'digged glockensp...|             374|             536|'limeades iteranc...|                null|             813|
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+----------------+----------------+--------------------+--------------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ### Q3

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?product ?label ?p1 ?p3
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            # ?product bsbm:productPropertyNumeric3 ?p3 .
            FILTER (?p1 > 1800)
            FILTER (?p3 < 5 )
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.4152048689993535, 1.3532676089998859, 1.281841459000134, 1.3187303929998961, 1.2268315700002859, 1.1259463480000704, 1.0925609179994353, 1.090250668000408, 1.092925513999944, 1.0814043720001791]
#
# AVG_TIME
# 1.2078963719999591

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?product ?label ?p1 ?p3
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            # ?product bsbm:productPropertyNumeric3 ?p3 .
            FILTER (?p1 > 1800)
            FILTER (?p3 < 5 )
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +-------+-----+---+---+
# |product|label| p1| p3|
# +-------+-----+---+---+
# +-------+-----+---+---+

# %% [markdown]
# ### Q4

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?c ?propertyTextual ?p1
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?pcr .
            # ?pcr edm:country ?c .
            # ?pcr foaf:homepage ?h .
            # ?offer gr:validFrom ?vf .
            # ?offer bsbm:product ?product .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?product bsbm:productPropertyTextual1 ?propertyTextual .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            FILTER (?p1 > 630)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.6409293859996978, 1.5143511790001867, 1.4720671129998664, 1.4853957100003754, 1.5623859620000076, 1.466603200999998, 1.8230932810001832, 1.6267371320000166, 1.9787561120001556, 1.4888913079994381]
#
# AVG_TIME
# 1.6059210383999925

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?c ?propertyTextual ?p1
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?pcr .
            # ?pcr edm:country ?c .
            # ?pcr foaf:homepage ?h .
            # ?offer gr:validFrom ?vf .
            # ?offer bsbm:product ?product .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?product bsbm:productPropertyTextual1 ?propertyTextual .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            FILTER (?p1 > 630)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +--------------------+---+--------------------+----+
# |               label|  c|     propertyTextual|  p1|
# +--------------------+---+--------------------+----+
# |           'coterie'| DE|'scalded decoct p...|1891|
# |    'manner gatemen'| DE|'guzzling jillion...| 831|
# |'procreators taiw...| DE|'exceptionally re...|1504|
# |'reexhibit wrang ...| DE|'skinfuls uncerta...| 940|
# |'resettling uncoa...| DE|'unrestored kneel...|1743|
# |  'tither pettiness'| DE|'solidest incarna...|1900|
# |'vacillator morti...| DE|'egoisms welterwe...| 834|
# +--------------------+---+--------------------+----+

# %% [markdown]
# ### Q5

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?productLabel ?simProperty1 ?simProperty2
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product bsbm:productPropertyNumeric1 ?simProperty1 .
            # ?product bsbm:productPropertyNumeric2 ?simProperty2 .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?simProperty1 < 120)
            FILTER (?productLabel != "wineskins banded crc")
            FILTER (?simProperty2 < 170)
        }
        ORDER BY ?productLabel
        LIMIT 5
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.2483313510001608, 1.1526907839997875, 1.2019185660001312, 1.353941381000368, 1.284430734000125, 1.3256043119999958, 1.3318785020001087, 1.2719816759999958, 1.2185669350001263, 1.1202651530002186]
#
# AVG_TIME
# 1.2509609394001018

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?productLabel ?simProperty1 ?simProperty2
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product bsbm:productPropertyNumeric1 ?simProperty1 .
            # ?product bsbm:productPropertyNumeric2 ?simProperty2 .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?simProperty1 < 120)
            FILTER (?productLabel != "wineskins banded crc")
            FILTER (?simProperty2 < 170)
        }
        ORDER BY ?productLabel
        LIMIT 5
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +------------+------------+------------+
# |productLabel|simProperty1|simProperty2|
# +------------+------------+------------+
# +------------+------------+------------+

# %% [markdown]
# ### Q7

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?productLabel ?price ?vendor ?revTitle
        # ?reviewer ?rating1 ?rating2 ?product ?revName
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product rdf:type bsbm:Product .
            # ?offer bsbm:product ?product .
            # ?offer bsbm:price ?price .
            # ?offer bsbm:vendor ?vendor .
            # ?offer bsbm:validTo ?date .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?reviewer .
            # ?review dc:title ?revTitle .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?reviewer foaf:name ?revName .
            # ?reviewer a foaf:Person .
            FILTER (?price > 5000)
            FILTER (str(?product) = "http://example.com/Product/9")
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.5661725010004375, 1.4059532190003665, 1.6518069370004014, 1.687647785000081, 1.45523542599949, 1.4921913809994294, 1.4307240300004196, 1.4425667409996095, 1.4473819140002888, 1.3965456289997746]
#
# AVG_TIME
# 1.4976225563000298

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?productLabel ?price ?vendor ?revTitle
        # ?reviewer ?rating1 ?rating2 ?product ?revName
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product rdf:type bsbm:Product .
            # ?offer bsbm:product ?product .
            # ?offer bsbm:price ?price .
            # ?offer bsbm:vendor ?vendor .
            # ?offer bsbm:validTo ?date .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?reviewer .
            # ?review dc:title ?revTitle .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?reviewer foaf:name ?revName .
            # ?reviewer a foaf:Person .
            FILTER (?price > 5000)
            FILTER (str(?product) = "http://example.com/Product/9")
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +--------------------+---------+------+--------------------+--------------------+-------+-------+--------------------+--------------------+
# |        productLabel|    price|vendor|            revTitle|            reviewer|rating1|rating2|             product|             revName|
# +--------------------+---------+------+--------------------+--------------------+-------+-------+--------------------+--------------------+
# |'procreators taiw...|8.09271E3|     1|'improves pervert...|http://example.co...|      7|     10|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|9.23612E3|     1|'improves pervert...|http://example.co...|      7|     10|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|7.26904E3|     1|'slavishness muon...|http://example.co...|      5|     10|http://example.co...|  'Eyana-Aurelianus'|
# |'procreators taiw...|9.23612E3|     1|'slavishness muon...|http://example.co...|      5|     10|http://example.co...|  'Eyana-Aurelianus'|
# |'procreators taiw...|9.23612E3|     1|'recharting wardr...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|8.72534E3|     1|'heehawed underwa...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|6.95779E3|     1|'footworn forms n...|http://example.co...|      8|      5|http://example.co...|     'Przemek-Berte'|
# |'procreators taiw...|8.72534E3|     1|'slavishness muon...|http://example.co...|      5|     10|http://example.co...|  'Eyana-Aurelianus'|
# |'procreators taiw...|9.23612E3|     1|'footworn forms n...|http://example.co...|      8|      5|http://example.co...|     'Przemek-Berte'|
# |'procreators taiw...|8.72534E3|     1|'improves pervert...|http://example.co...|      7|     10|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|8.72534E3|     1|'affirmance subag...|http://example.co...|      2|      3|http://example.co...|  'Allegra-Walburga'|
# |'procreators taiw...|7.26904E3|     1|'improves pervert...|http://example.co...|      7|     10|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|9.23612E3|     1|'affirmance subag...|http://example.co...|      2|      3|http://example.co...|  'Allegra-Walburga'|
# |'procreators taiw...|8.09271E3|     1|'slavishness muon...|http://example.co...|      5|     10|http://example.co...|  'Eyana-Aurelianus'|
# |'procreators taiw...|6.95779E3|     1|'affirmance subag...|http://example.co...|      2|      3|http://example.co...|  'Allegra-Walburga'|
# |'procreators taiw...|6.95779E3|     1|'heehawed underwa...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|8.72534E3|     1|'recharting wardr...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|7.26904E3|     1|'footworn forms n...|http://example.co...|      8|      5|http://example.co...|     'Przemek-Berte'|
# |'procreators taiw...|8.09271E3|     1|'heehawed underwa...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# |'procreators taiw...|7.26904E3|     1|'recharting wardr...|http://example.co...|     -1|      4|http://example.co...|'Danijela-Adalbrand'|
# +--------------------+---------+------+--------------------+--------------------+-------+-------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Q8

# %%
# Runt the test

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?title ?text ?reviewDate ?reviewer
                        # ?reviewerName ?rating1 ?rating2
                        # ?rating3 ?rating4 ?product
        WHERE {
            # ?product rdfs:label  ?label .
            # ?product bsbm:productPropertyTextual1 ?pt .
            # ?product bsbm:producer ?producer .
            # ?producer edm:country ?c .
            # ?producer foaf:homepage ?h .
            # ?review bsbm:reviewFor ?product .
            # ?review dc:title ?title .
            # ?review rev:text ?text .
            # ?review bsbm:reviewDate ?reviewDate .
            # ?review rev:reviewer ?reviewer .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?review bsbm:rating3 ?rating3 .
            # ?review bsbm:rating4 ?rating4 .
            # ?reviewer foaf:name ?reviewerName .
            # ?reviewer a foaf:Person .
            FILTER (str(?product) = "http://example.com/Product/9")
        }
        ORDER BY DESC(?reviewDate)
        LIMIT 9
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [2.0529662589997315, 1.926983907000249, 2.010208208000222, 1.6466033329998027, 2.0347125990001587, 1.650691179000205, 1.7891909820000365, 1.6625204680003662, 1.6934222979998594, 1.6864905579996048]
#
# AVG_TIME
# 1.8153789791000237

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?title ?text ?reviewDate ?reviewer
                        # ?reviewerName ?rating1 ?rating2
                        # ?rating3 ?rating4 ?product
        WHERE {
            # ?product rdfs:label  ?label .
            # ?product bsbm:productPropertyTextual1 ?pt .
            # ?product bsbm:producer ?producer .
            # ?producer edm:country ?c .
            # ?producer foaf:homepage ?h .
            # ?review bsbm:reviewFor ?product .
            # ?review dc:title ?title .
            # ?review rev:text ?text .
            # ?review bsbm:reviewDate ?reviewDate .
            # ?review rev:reviewer ?reviewer .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?review bsbm:rating3 ?rating3 .
            # ?review bsbm:rating4 ?rating4 .
            # ?reviewer foaf:name ?reviewerName .
            # ?reviewer a foaf:Person .
            FILTER (str(?product) = "http://example.com/Product/9")
        }
        ORDER BY DESC(?reviewDate)
        LIMIT 9
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

resultDF.show()  # Plot the results
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+-------+-------+-------+-------+--------------------+
# |               title|                text|reviewDate|            reviewer|        reviewerName|rating1|rating2|rating3|rating4|             product|
# +--------------------+--------------------+----------+--------------------+--------------------+-------+-------+-------+-------+--------------------+
# |'heehawed underwa...|'brisker astrophy...|2008-03-23|http://example.co...|'Danijela-Adalbrand'|     -1|      4|     -1|      9|http://example.co...|
# |'affirmance subag...|'southwesterners ...|2008-01-16|http://example.co...|  'Allegra-Walburga'|      2|      3|     10|      6|http://example.co...|
# |'slavishness muon...|'philatelist lugu...|2008-01-14|http://example.co...|  'Eyana-Aurelianus'|      5|     10|     -1|     -1|http://example.co...|
# |'footworn forms n...|'breedings silenc...|2007-12-04|http://example.co...|     'Przemek-Berte'|      8|      5|      2|      1|http://example.co...|
# |'recharting wardr...|'moxas clangored ...|2007-11-16|http://example.co...|'Danijela-Adalbrand'|     -1|      4|      7|     10|http://example.co...|
# |'improves pervert...|'mapping construc...|2007-11-16|http://example.co...|'Danijela-Adalbrand'|      7|     10|      2|      8|http://example.co...|
# +--------------------+--------------------+----------+--------------------+--------------------+-------+-------+-------+-------+--------------------+
