# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, HiveContext
from pyspark.sql.functions import *

# %%
from IPython.display import display
import pandas as pd

# %%
from PySPARQL.Wrapper import PySPARQLWrapper

# %%
import timeit
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Connection to Apache Spark

# %%
spark = (SparkSession
          .builder
          .appName("interfacing spark sql to hive metastore without configuration file")
          .config("hive.metastore.uris", "thrift://hive-metastore:9083") 
          .enableHiveSupport() 
          .getOrCreate())

# %% [markdown]
# ### SPARQL query endpoint

# %%
sparql_endpoint = "http://ontop:8080/sparql"

# %% [markdown]
# ### Timeit configuration

# %%
repeat = 10
loop = 1

def Average(lst):
    total = 0
    for ele in range(0, len(lst)):
        total = total + lst[ele]
    return total / len(lst)

# %% [markdown]
# ### Q1

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?value
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:productPropertyNumeric1 ?value .
            # ?product rdf:type bsbm:Product .
            # ?product bsbm:producer ?producer .
            # ?producer rdf:type bsbm:Producer .
            # ?producer foaf:homepage ?hp .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?value > 102)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.9698936240001785, 1.776905861999694, 1.6356732259991986, 1.2230020500001046, 1.3031294909997087, 1.8124921300004644, 1.3802593139998862, 1.3958868429999711, 1.5133209960004024, 1.4760353740002756]
#
# AVG_TIME
# 1.5486598909999885

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?value
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:productPropertyNumeric1 ?value .
            # ?product rdf:type bsbm:Product .
            # ?product bsbm:producer ?producer .
            # ?producer rdf:type bsbm:Producer .
            # ?producer foaf:homepage ?hp .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?value > 102)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                               label value
# 0                          'ahchoo'   594
# 1                         'coterie'  1891
# 2      'desolates waging reveilles'   374
# 3      'lignites rallying specters'   133
# 4                  'manner gatemen'   831
# 5  'procreators taiwanese antigene'  1504
# 6           'reexhibit wrang tarts'   940
# 7  'resettling uncoagulated lowish'  1743
# 8                'tither pettiness'  1900
# 9           'vacillator mortifying'   834

# %% [markdown]
# ### Q2

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?label ?comment ?producer ?price
            # ?propertyTextual1 ?propertyTextual2 ?propertyTextual3
            # ?propertyNumeric1 ?propertyNumeric2 ?propertyTextual4
            # ?propertyTextual5 ?propertyNumeric4
        WHERE {
            # ?p rdfs:label ?label .
            # ?p rdfs:comment ?comment .
            # ?p bsbm:producer ?producer .
            # ?p dc:publisher ?ps .
            # ?offer bsbm:product ?p .
            # ?offer bsbm:price ?price .
            # ?p bsbm:productPropertyTextual1 ?propertyTextual1 .
            # ?p bsbm:productPropertyTextual2 ?propertyTextual2 .
            # ?p bsbm:productPropertyTextual3 ?propertyTextual3 .
            # ?p bsbm:productPropertyNumeric1 ?propertyNumeric1 .
            # ?p bsbm:productPropertyNumeric2 ?propertyNumeric2 .
            # ?p bsbm:productPropertyTextual4 ?propertyTextual4 .
            # ?p bsbm:productPropertyTextual5 ?propertyTextual5 .
            # ?p bsbm:productPropertyNumeric4 ?propertyNumeric4 .
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [2.6481286369998998, 2.013073076999717, 1.3909098190006262, 1.7910241549998318, 1.4756068000006053, 1.5118295810007112, 2.581986535999931, 1.5044501989996206, 1.2923217909992673, 1.2762878249995993]
#
# AVG_TIME
# 1.7485618419999809

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?label ?comment ?producer ?price
            # ?propertyTextual1 ?propertyTextual2 ?propertyTextual3
            # ?propertyNumeric1 ?propertyNumeric2 ?propertyTextual4
            # ?propertyTextual5 ?propertyNumeric4
        WHERE {
            # ?p rdfs:label ?label .
            # ?p rdfs:comment ?comment .
            # ?p bsbm:producer ?producer .
            # ?p dc:publisher ?ps .
            # ?offer bsbm:product ?p .
            # ?offer bsbm:price ?price .
            # ?p bsbm:productPropertyTextual1 ?propertyTextual1 .
            # ?p bsbm:productPropertyTextual2 ?propertyTextual2 .
            # ?p bsbm:productPropertyTextual3 ?propertyTextual3 .
            # ?p bsbm:productPropertyNumeric1 ?propertyNumeric1 .
            # ?p bsbm:productPropertyNumeric2 ?propertyNumeric2 .
            # ?p bsbm:productPropertyTextual4 ?propertyTextual4 .
            # ?p bsbm:productPropertyTextual5 ?propertyTextual5 .
            # ?p bsbm:productPropertyNumeric4 ?propertyNumeric4 .
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                                 label  \
# 0                            'ahchoo'
# 1                            'ahchoo'
# 2             'vacillator mortifying'
# 3        'desolates waging reveilles'
# 4                  'tither pettiness'
# ..                                ...
# 195           'reexhibit wrang tarts'
# 196                'tither pettiness'
# 197  'resettling uncoagulated lowish'
# 198                  'manner gatemen'
# 199           'vacillator mortifying'
#
#                                                comment  \
# 0    'chanceman ventrals phlegmy vower matureness f...
# 1    'chanceman ventrals phlegmy vower matureness f...
# 2    'workaholics situating repartees mobilizers an...
# 3    'poleward sagest impellers enjoyed tailpipes r...
# 4    'buskin recompensable capacitances bootee lock...
# ..                                                 ...
# 195  'bihourly prosiest matrixes jaggedest violinis...
# 196  'buskin recompensable capacitances bootee lock...
# 197  'reprice renovating chevrolets refolds fantast...
# 198  'lordlings dialyzed hoardings palmitate resist...
# 199  'workaholics situating repartees mobilizers an...
#
#                           producer      price  \
# 0    http://example.com/Producer/1  8.56176E3
# 1    http://example.com/Producer/1  3.03146E3
# 2    http://example.com/Producer/1  8.35118E3
# 3    http://example.com/Producer/1  9.54292E3
# 4    http://example.com/Producer/1  7.09958E3
# ..                             ...        ...
# 195  http://example.com/Producer/1  7.63992E3
# 196  http://example.com/Producer/1  9.20969E3
# 197  http://example.com/Producer/1  2.06776E3
# 198  http://example.com/Producer/1  1.49017E3
# 199  http://example.com/Producer/1  4.24145E3
#
#                                       propertyTextual1  \
# 0    'whirs radiation overman violative adulators b...
# 1    'whirs radiation overman violative adulators b...
# 2    'egoisms welterweight friendship topsoiling se...
# 3    'catarrhs triadisms foreseen wennier scurviest...
# 4    'solidest incarnation arrayers gruelingly hono...
# ..                                                 ...
# 195  'skinfuls uncertainty craving incas maenades f...
# 196  'solidest incarnation arrayers gruelingly hono...
# 197  'unrestored kneeler chaplet newts deckle vegas...
# 198  'guzzling jillion psychotherapists substantiat...
# 199  'egoisms welterweight friendship topsoiling se...
#
#                                       propertyTextual2  \
# 0    'vichies resituates breads visard unfought adj...
# 1    'vichies resituates breads visard unfought adj...
# 2         'unacceptance antibody reinflamed rehardens'
# 3    'chilblains intertribal balsamic exotism reint...
# 4    'builders preadjusting cpl fosterage trulls fa...
# ..                                                 ...
# 195  'quartered mishmosh booms globoid syndicating ...
# 196  'builders preadjusting cpl fosterage trulls fa...
# 197  'replicates corks cinematheques charmers licit...
# 198  'recommendation embezzler reconviction misprop...
# 199       'unacceptance antibody reinflamed rehardens'
#
#                                       propertyTextual3 propertyNumeric1  \
# 0    'unreels voicer acidifiers shredding fistula u...              594
# 1    'unreels voicer acidifiers shredding fistula u...              594
# 2    'steeper aerifies unum overbalanced discipline...              834
# 3    'digged glockenspiels hearted sapid weeny coll...              374
# 4    'dermatologies flopover noctambulation frizzle...             1900
# ..                                                 ...              ...
# 195  'visas deprecatingly conceptualist reactivatio...              940
# 196  'dermatologies flopover noctambulation frizzle...             1900
# 197        'cowiest crimpers unmuzzles repacify poilu'             1743
# 198  'decentralizations impacting promulgations bib...              831
# 199  'steeper aerifies unum overbalanced discipline...              834
#
#     propertyNumeric2                                   propertyTextual4  \
# 0                434                                               null
# 1                434                                               null
# 2                450                                               null
# 3                536  'limeades iterances expressionist sculked supp...
# 4                774                                               null
# ..               ...                                                ...
# 195              290                                               null
# 196              774                                               null
# 197              136                                               null
# 198              312         'distracts universally trashily enervator'
# 199              450                                               null
#
#                    propertyTextual5 propertyNumeric4
# 0    'hyperbolas knouted eulogists'               -1
# 1    'hyperbolas knouted eulogists'               -1
# 2                              null              202
# 3                              null              813
# 4                              null               -1
# ..                              ...              ...
# 195                            null               -1
# 196                            null               -1
# 197                            null               -1
# 198                            null               -1
# 199                            null              202
#
# [200 rows x 12 columns]

# %% [markdown]
# ### Q3

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?product ?label ?p1 ?p3
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            # ?product bsbm:productPropertyNumeric3 ?p3 .
            FILTER (?p1 > 1800)
            FILTER (?p3 < 5 )
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.27481309399991, 0.6865023899999869, 0.8077077090001694, 1.0947284320000108, 1.0224303380000492, 0.9940615169998637, 0.8249554069998339, 0.8511201930004972, 0.8374584960001812, 0.7681802589995641]
#
# AVG_TIME
# 0.9161957835000066

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?product ?label ?p1 ?p3
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            # ?product bsbm:productPropertyNumeric3 ?p3 .
            FILTER (?p1 > 1800)
            FILTER (?p3 < 5 )
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
# Empty DataFrame
# Columns: [product, label, p1, p3]
# Index: []

# %% [markdown]
# ### Q4

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?c ?propertyTextual ?p1
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?pcr .
            # ?pcr edm:country ?c .
            # ?pcr foaf:homepage ?h .
            # ?offer gr:validFrom ?vf .
            # ?offer bsbm:product ?product .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?product bsbm:productPropertyTextual1 ?propertyTextual .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            FILTER (?p1 > 630)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.3783949899998333, 1.5600478980004482, 1.270196228999339, 1.571367683999597, 1.4738308010000765, 0.9898938100004671, 1.1092333090000466, 1.1712226170002396, 1.0478586429999268, 1.1309514750000744]
#
# AVG_TIME
# 1.270299745600005

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?label ?c ?propertyTextual ?p1
        WHERE {
            # ?product rdfs:label ?label .
            # ?product bsbm:producer ?pcr .
            # ?pcr edm:country ?c .
            # ?pcr foaf:homepage ?h .
            # ?offer gr:validFrom ?vf .
            # ?offer bsbm:product ?product .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?pers .
            # ?pers foaf:name ?fn .
            # ?pers edm:country ?cn .
            # ?product bsbm:productPropertyTextual1 ?propertyTextual .
            # ?product bsbm:productPropertyNumeric1 ?p1 .
            FILTER (?p1 > 630)
        }
        ORDER BY ?label
        LIMIT 10
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                               label   c  \
# 0                         'coterie'  DE
# 1                  'manner gatemen'  DE
# 2  'procreators taiwanese antigene'  DE
# 3           'reexhibit wrang tarts'  DE
# 4  'resettling uncoagulated lowish'  DE
# 5                'tither pettiness'  DE
# 6           'vacillator mortifying'  DE
#
#                                      propertyTextual    p1
# 0  'scalded decoct practitioners infolds levered ...  1891
# 1  'guzzling jillion psychotherapists substantiat...   831
# 2  'exceptionally replan aiming bedstraws tragica...  1504
# 3  'skinfuls uncertainty craving incas maenades f...   940
# 4  'unrestored kneeler chaplet newts deckle vegas...  1743
# 5  'solidest incarnation arrayers gruelingly hono...  1900
# 6  'egoisms welterweight friendship topsoiling se...   834

# %% [markdown]
# ### Q5

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?productLabel ?simProperty1 ?simProperty2
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product bsbm:productPropertyNumeric1 ?simProperty1 .
            # ?product bsbm:productPropertyNumeric2 ?simProperty2 .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?simProperty1 < 120)
            FILTER (?productLabel != "wineskins banded crc")
            FILTER (?simProperty2 < 170)
        }
        ORDER BY ?productLabel
        LIMIT 5
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.2590977930003646, 1.173136956000235, 1.1335630889998356, 1.1543671050003468, 1.1225111929998093, 1.156528384000012, 1.1621529079993707, 1.2123576220001269, 1.293971555999633, 1.3598593779997827]
#
# AVG_TIME
# 1.2027545983999517

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?productLabel ?simProperty1 ?simProperty2
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product bsbm:productPropertyNumeric1 ?simProperty1 .
            # ?product bsbm:productPropertyNumeric2 ?simProperty2 .
            # ?product bsbm:producer ?producer .
            # ?review bsbm:reviewFor ?product .
            # ?review rdf:type schema:Review .
            # ?offer bsbm:product ?product .
            # ?offer rdf:type schema:Offer .
            FILTER (?simProperty1 < 120)
            FILTER (?productLabel != "wineskins banded crc")
            FILTER (?simProperty2 < 170)
        }
        ORDER BY ?productLabel
        LIMIT 5
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
# Empty DataFrame
# Columns: [productLabel, simProperty1, simProperty2]
# Index: []

# %% [markdown]
# ### Q7

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?productLabel ?price ?vendor ?revTitle
        # ?reviewer ?rating1 ?rating2 ?product ?revName
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product rdf:type bsbm:Product .
            # ?offer bsbm:product ?product .
            # ?offer bsbm:price ?price .
            # ?offer bsbm:vendor ?vendor .
            # ?offer bsbm:validTo ?date .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?reviewer .
            # ?review dc:title ?revTitle .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?reviewer foaf:name ?revName .
            # ?reviewer a foaf:Person .
            FILTER (?price > 5000)
            FILTER (str(?product) = "http://example.com/Product/9")
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.5266206239994062, 1.4740476220003984, 1.4697140189991842, 1.4501250019993677, 1.4997575239995058, 1.5712831569999253, 1.492969947000347, 1.4701914369998121, 1.4815737540002374, 1.913996013000542]
#
# AVG_TIME
# 1.5350279098998727

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT ?productLabel ?price ?vendor ?revTitle
        # ?reviewer ?rating1 ?rating2 ?product ?revName
        WHERE {
            # ?product rdfs:label ?productLabel .
            # ?product rdf:type bsbm:Product .
            # ?offer bsbm:product ?product .
            # ?offer bsbm:price ?price .
            # ?offer bsbm:vendor ?vendor .
            # ?offer bsbm:validTo ?date .
            # ?review bsbm:reviewFor ?product .
            # ?review rev:reviewer ?reviewer .
            # ?review dc:title ?revTitle .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?reviewer foaf:name ?revName .
            # ?reviewer a foaf:Person .
            FILTER (?price > 5000)
            FILTER (str(?product) = "http://example.com/Product/9")
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                         productLabel      price vendor  \
# 0   'procreators taiwanese antigene'  8.09271E3      1
# 1   'procreators taiwanese antigene'  9.23612E3      1
# 2   'procreators taiwanese antigene'  7.26904E3      1
# 3   'procreators taiwanese antigene'  9.23612E3      1
# 4   'procreators taiwanese antigene'  9.23612E3      1
# 5   'procreators taiwanese antigene'  8.72534E3      1
# 6   'procreators taiwanese antigene'  6.95779E3      1
# 7   'procreators taiwanese antigene'  8.72534E3      1
# 8   'procreators taiwanese antigene'  9.23612E3      1
# 9   'procreators taiwanese antigene'  8.72534E3      1
# 10  'procreators taiwanese antigene'  8.72534E3      1
# 11  'procreators taiwanese antigene'  7.26904E3      1
# 12  'procreators taiwanese antigene'  9.23612E3      1
# 13  'procreators taiwanese antigene'  8.09271E3      1
# 14  'procreators taiwanese antigene'  6.95779E3      1
# 15  'procreators taiwanese antigene'  6.95779E3      1
# 16  'procreators taiwanese antigene'  8.72534E3      1
# 17  'procreators taiwanese antigene'  7.26904E3      1
# 18  'procreators taiwanese antigene'  8.09271E3      1
# 19  'procreators taiwanese antigene'  7.26904E3      1
# 20  'procreators taiwanese antigene'  8.09271E3      1
# 21  'procreators taiwanese antigene'  8.09271E3      1
# 22  'procreators taiwanese antigene'  7.26904E3      1
# 23  'procreators taiwanese antigene'  6.95779E3      1
# 24  'procreators taiwanese antigene'  6.95779E3      1
# 25  'procreators taiwanese antigene'  8.72534E3      1
# 26  'procreators taiwanese antigene'  9.23612E3      1
# 27  'procreators taiwanese antigene'  7.26904E3      1
# 28  'procreators taiwanese antigene'  6.95779E3      1
# 29  'procreators taiwanese antigene'  8.09271E3      1
#
#                                              revTitle  \
# 0             'improves pervertedly kevils canneries'
# 1             'improves pervertedly kevils canneries'
# 2   'slavishness muonic unencumbered horsepox vine...
# 3   'slavishness muonic unencumbered horsepox vine...
# 4   'recharting wardrobes divvies rhetorics phanta...
# 5   'heehawed underway knickers scroungier hypnoti...
# 6   'footworn forms nonflammable abator editoriali...
# 7   'slavishness muonic unencumbered horsepox vine...
# 8   'footworn forms nonflammable abator editoriali...
# 9             'improves pervertedly kevils canneries'
# 10  'affirmance subagency diptych donne tipoffs ro...
# 11            'improves pervertedly kevils canneries'
# 12  'affirmance subagency diptych donne tipoffs ro...
# 13  'slavishness muonic unencumbered horsepox vine...
# 14  'affirmance subagency diptych donne tipoffs ro...
# 15  'heehawed underway knickers scroungier hypnoti...
# 16  'recharting wardrobes divvies rhetorics phanta...
# 17  'footworn forms nonflammable abator editoriali...
# 18  'heehawed underway knickers scroungier hypnoti...
# 19  'recharting wardrobes divvies rhetorics phanta...
# 20  'footworn forms nonflammable abator editoriali...
# 21  'affirmance subagency diptych donne tipoffs ro...
# 22  'heehawed underway knickers scroungier hypnoti...
# 23  'recharting wardrobes divvies rhetorics phanta...
# 24            'improves pervertedly kevils canneries'
# 25  'footworn forms nonflammable abator editoriali...
# 26  'heehawed underway knickers scroungier hypnoti...
# 27  'affirmance subagency diptych donne tipoffs ro...
# 28  'slavishness muonic unencumbered horsepox vine...
# 29  'recharting wardrobes divvies rhetorics phanta...
#
#                        reviewer rating1 rating2                       product  \
# 0   http://example.com/Person/3       7      10  http://example.com/Product/9
# 1   http://example.com/Person/3       7      10  http://example.com/Product/9
# 2   http://example.com/Person/2       5      10  http://example.com/Product/9
# 3   http://example.com/Person/2       5      10  http://example.com/Product/9
# 4   http://example.com/Person/3      -1       4  http://example.com/Product/9
# 5   http://example.com/Person/3      -1       4  http://example.com/Product/9
# 6   http://example.com/Person/5       8       5  http://example.com/Product/9
# 7   http://example.com/Person/2       5      10  http://example.com/Product/9
# 8   http://example.com/Person/5       8       5  http://example.com/Product/9
# 9   http://example.com/Person/3       7      10  http://example.com/Product/9
# 10  http://example.com/Person/4       2       3  http://example.com/Product/9
# 11  http://example.com/Person/3       7      10  http://example.com/Product/9
# 12  http://example.com/Person/4       2       3  http://example.com/Product/9
# 13  http://example.com/Person/2       5      10  http://example.com/Product/9
# 14  http://example.com/Person/4       2       3  http://example.com/Product/9
# 15  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 16  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 17  http://example.com/Person/5       8       5  http://example.com/Product/9
# 18  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 19  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 20  http://example.com/Person/5       8       5  http://example.com/Product/9
# 21  http://example.com/Person/4       2       3  http://example.com/Product/9
# 22  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 23  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 24  http://example.com/Person/3       7      10  http://example.com/Product/9
# 25  http://example.com/Person/5       8       5  http://example.com/Product/9
# 26  http://example.com/Person/3      -1       4  http://example.com/Product/9
# 27  http://example.com/Person/4       2       3  http://example.com/Product/9
# 28  http://example.com/Person/2       5      10  http://example.com/Product/9
# 29  http://example.com/Person/3      -1       4  http://example.com/Product/9
#
#                  revName
# 0   'Danijela-Adalbrand'
# 1   'Danijela-Adalbrand'
# 2     'Eyana-Aurelianus'
# 3     'Eyana-Aurelianus'
# 4   'Danijela-Adalbrand'
# 5   'Danijela-Adalbrand'
# 6        'Przemek-Berte'
# 7     'Eyana-Aurelianus'
# 8        'Przemek-Berte'
# 9   'Danijela-Adalbrand'
# 10    'Allegra-Walburga'
# 11  'Danijela-Adalbrand'
# 12    'Allegra-Walburga'
# 13    'Eyana-Aurelianus'
# 14    'Allegra-Walburga'
# 15  'Danijela-Adalbrand'
# 16  'Danijela-Adalbrand'
# 17       'Przemek-Berte'
# 18  'Danijela-Adalbrand'
# 19  'Danijela-Adalbrand'
# 20       'Przemek-Berte'
# 21    'Allegra-Walburga'
# 22  'Danijela-Adalbrand'
# 23  'Danijela-Adalbrand'
# 24  'Danijela-Adalbrand'
# 25       'Przemek-Berte'
# 26  'Danijela-Adalbrand'
# 27    'Allegra-Walburga'
# 28    'Eyana-Aurelianus'
# 29  'Danijela-Adalbrand'

# %% [markdown]
# ### Q8

# %%
# Get execution times

code ='''
query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?title ?text ?reviewDate ?reviewer
                        # ?reviewerName ?rating1 ?rating2
                        # ?rating3 ?rating4 ?product
        WHERE {
            # ?product rdfs:label  ?label .
            # ?product bsbm:productPropertyTextual1 ?pt .
            # ?product bsbm:producer ?producer .
            # ?producer edm:country ?c .
            # ?producer foaf:homepage ?h .
            # ?review bsbm:reviewFor ?product .
            # ?review dc:title ?title .
            # ?review rev:text ?text .
            # ?review bsbm:reviewDate ?reviewDate .
            # ?review rev:reviewer ?reviewer .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?review bsbm:rating3 ?rating3 .
            # ?review bsbm:rating4 ?rating4 .
            # ?reviewer foaf:name ?reviewerName .
            # ?reviewer a foaf:Person .
            FILTER (str(?product) = "http://example.com/Product/9")
        }
        ORDER BY DESC(?reviewDate)
        LIMIT 9
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [1.7959132030000546, 1.7305863510000563, 1.8966450699999768, 1.9551388760000918, 1.8935270570000284, 1.8750050440003179, 1.926615794999634, 2.159048728999551, 1.9835431880001124, 1.8991601660000015]
#
# AVG_TIME
# 1.9115183478999824

# %%
# Run the query

query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
        PREFIX schema: <http://schema.org/>
        PREFIX rev: <http://purl.org/stuff/rev#>
        PREFIX edm: <http://www.europeana.eu/schemas/edm/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX gr: <http://purl.org/goodrelations/v1#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX bsbm: <http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01/vocabulary/>

        SELECT DISTINCT ?title ?text ?reviewDate ?reviewer
                        # ?reviewerName ?rating1 ?rating2
                        # ?rating3 ?rating4 ?product
        WHERE {
            # ?product rdfs:label  ?label .
            # ?product bsbm:productPropertyTextual1 ?pt .
            # ?product bsbm:producer ?producer .
            # ?producer edm:country ?c .
            # ?producer foaf:homepage ?h .
            # ?review bsbm:reviewFor ?product .
            # ?review dc:title ?title .
            # ?review rev:text ?text .
            # ?review bsbm:reviewDate ?reviewDate .
            # ?review rev:reviewer ?reviewer .
            # ?review bsbm:rating1 ?rating1 .
            # ?review bsbm:rating2 ?rating2 .
            # ?review bsbm:rating3 ?rating3 .
            # ?review bsbm:rating4 ?rating4 .
            # ?reviewer foaf:name ?reviewerName .
            # ?reviewer a foaf:Person .
            FILTER (str(?product) = "http://example.com/Product/9")
        }
        ORDER BY DESC(?reviewDate)
        LIMIT 9
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                                                title  \
# 0  'heehawed underway knickers scroungier hypnoti...
# 1  'affirmance subagency diptych donne tipoffs ro...
# 2  'slavishness muonic unencumbered horsepox vine...
# 3  'footworn forms nonflammable abator editoriali...
# 4  'recharting wardrobes divvies rhetorics phanta...
# 5            'improves pervertedly kevils canneries'
#
#                                                 text  reviewDate  \
# 0  'brisker astrophysicists elations chlorines va...  2008-03-23
# 1  'southwesterners denier bicycles veneers super...  2008-01-16
# 2  'philatelist lugubrious unknots hummocky gonge...  2008-01-14
# 3  'breedings silences respirating litterateurs e...  2007-12-04
# 4  'moxas clangored haughtier rascals southerly s...  2007-11-16
# 5  'mapping constructions motiveless stalkier val...  2007-11-16
#
#                       reviewer          reviewerName rating1 rating2 rating3  \
# 0  http://example.com/Person/3  'Danijela-Adalbrand'      -1       4      -1
# 1  http://example.com/Person/4    'Allegra-Walburga'       2       3      10
# 2  http://example.com/Person/2    'Eyana-Aurelianus'       5      10      -1
# 3  http://example.com/Person/5       'Przemek-Berte'       8       5       2
# 4  http://example.com/Person/3  'Danijela-Adalbrand'      -1       4       7
# 5  http://example.com/Person/3  'Danijela-Adalbrand'       7      10       2
#
#   rating4                       product
# 0       9  http://example.com/Product/9
# 1       6  http://example.com/Product/9
# 2      -1  http://example.com/Product/9
# 3       1  http://example.com/Product/9
# 4      10  http://example.com/Product/9
# 5       8  http://example.com/Product/9

# %% [markdown]
# # Free ?subj and ?pred

# %%
# Get execution times

code ='''
query = """
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

        SELECT ?subj ?pred
        WHERE {
            # ?subj ?pred "1"^^xsd:int.
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=repeat, globals=globals() , number=loop)

print("TIME")
print(result)

print("\nAVG_TIME")
print(Average(result))
# Out:
# TIME
# [15.576336842000273, 12.693113297000309, 12.37595686899931, 12.529332037999666, 12.527171355999599, 13.605895274000432, 12.628288398000223, 12.030420683000557, 12.188646896000137, 12.152942999000516]
#
# AVG_TIME
# 12.830810465200102

# %%
# Run the query

query = """
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

        SELECT ?subj ?pred
        WHERE {
            # ?subj ?pred "1"^^xsd:int.
        }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                               subj  \
# 0     http://example.com/Review/31
# 1     http://example.com/Review/65
# 2     http://example.com/Review/94
# 3     http://example.com/Review/59
# 4     http://example.com/Review/10
# ..                             ...
# 558   http://example.com/Product/4
# 559   http://example.com/Product/8
# 560   http://example.com/Product/7
# 561  http://example.com/Product/10
# 562   http://example.com/Product/2
#
#                                                   pred
# 0    http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 1    http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 2    http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 3    http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 4    http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# ..                                                 ...
# 558          http://purl.org/dc/elements/1.1/publisher
# 559          http://purl.org/dc/elements/1.1/publisher
# 560          http://purl.org/dc/elements/1.1/publisher
# 561          http://purl.org/dc/elements/1.1/publisher
# 562          http://purl.org/dc/elements/1.1/publisher
#
# [563 rows x 2 columns]

# %% [markdown]
# # Entailment regime query
# __attention__: usually takes several minutes

# %%
# Get execution time (only 1 iteration)

code ='''
query = """
    SELECT ?s ?p ?o 
    WHERE { 
        # ?s ?p ?o 
    }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
'''

result = timeit.repeat(code, repeat=1, globals=globals() , number=1)

print("TIME")
print(result)
# Out:
# TIME
# [201.38486229599948]

# %%
# Run the query

query = """
    SELECT ?s ?p ?o 
    WHERE { 
        # ?s ?p ?o 
    }
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame

# Visual plot
pandasDF = resultDF.toPandas()
display(pandasDF)
# Out:
#                                   s  \
# 0      http://example.com/Review/43
# 1      http://example.com/Review/92
# 2      http://example.com/Review/59
# 3      http://example.com/Review/16
# 4      http://example.com/Review/34
# ...                             ...
# 5086   http://example.com/Product/1
# 5087  http://example.com/Product/10
# 5088   http://example.com/Product/6
# 5089   http://example.com/Product/2
# 5090   http://example.com/Product/4
#
#                                                       p  \
# 0     http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 1     http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 2     http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 3     http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# 4     http://www4.wiwiss.fu-berlin.de/bizer/bsbm/v01...
# ...                                                 ...
# 5086       http://www.w3.org/2000/01/rdf-schema#comment
# 5087       http://www.w3.org/2000/01/rdf-schema#comment
# 5088       http://www.w3.org/2000/01/rdf-schema#comment
# 5089       http://www.w3.org/2000/01/rdf-schema#comment
# 5090       http://www.w3.org/2000/01/rdf-schema#comment
#
#                                                       o
# 0                          http://example.com/Product/7
# 1                          http://example.com/Product/2
# 2                          http://example.com/Product/7
# 3                          http://example.com/Product/3
# 4                          http://example.com/Product/5
# ...                                                 ...
# 5086  'lordlings dialyzed hoardings palmitate resist...
# 5087  'filaree cirque vibrations leukemoid enquirer ...
# 5088  'poleward sagest impellers enjoyed tailpipes r...
# 5089  'naughtiness illuminating careerers computeres...
# 5090  'bihourly prosiest matrixes jaggedest violinis...
#
# [5091 rows x 3 columns]
